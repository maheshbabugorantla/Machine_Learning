# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

true_false = lambda x: 1 if x else 0

human_faces = [true_false(face_detector(file)) for file in human_files_short]
dog_human_faces = [true_false(face_detector(file)) for file in dog_files_short]

print("{}% of Human images have human faces".format((sum(human_faces)/100)*100))
print("{}% of Dog images have human faces".format((sum(dog_human_faces)/100)*100))
# Out:
# 99.0% of Human images have human faces
# 12.0% of Dog images have human faces

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.
# Finding dog images with human faces
dog_with_human_faces = list()

for ind, val in enumerate(dog_human_faces):
    if val:
        dog_with_human_faces.append(dog_files_short[ind])

def draw_dog_face(path):
    img = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()

draw_dog_face(dog_with_human_faces[10])

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image
from IPython.display import display
from PIL import Image
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

human_faces = [true_false(dog_detector(file)) for file in human_files_short]
dog_human_faces = [true_false(dog_detector(file)) for file in dog_files_short]

print("{}% of Human images have dog faces".format((sum(human_faces)/100)*100))
print("{}% of Dog images have dog faces".format((sum(dog_human_faces)/100)*100))
# Out:
# 1.0% of Human images have dog faces
# 100.0% of Dog images have dog faces

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [00:36<00:00, 183.46it/s]
# 100%|██████████| 835/835 [00:30<00:00, 27.72it/s]
# 100%|██████████| 836/836 [00:24<00:00, 33.75it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization

input_shape = train_tensors[0].shape

model = Sequential()

# ### TODO: Define your architecture.
model.add(Conv2D(filters=16, kernel_size=3, padding='same', kernel_initializer='lecun_normal', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=32, kernel_size=3, padding='same', kernel_initializer='lecun_normal'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))


model.add(Conv2D(filters=64, kernel_size=3, padding='same', kernel_initializer='lecun_normal'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=128, kernel_size=3, padding='same', kernel_initializer='lecun_normal'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=256, kernel_size=3, padding='same', kernel_initializer='lecun_normal'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(GlobalAveragePooling2D())
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 112, 112, 16)      64
# _________________________________________________________________
# activation_55 (Activation)   (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 56, 56, 32)        128
# _________________________________________________________________
# activation_56 (Activation)   (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_57 (Activation)   (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_58 (Activation)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 7, 256)         1024
# _________________________________________________________________
# activation_59 (Activation)   (None, 7, 7, 256)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               34181
# =================================================================
# Total params: 428,773
# Trainable params: 427,781
# Non-trainable params: 992
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 50

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch_adam.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=128, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/50
# 6680/6680 [==============================] - 12s 2ms/step - loss: 4.7828 - acc: 0.0268 - val_loss: 4.8502 - val_acc: 0.0263
#
# Epoch 00001: val_loss improved from inf to 4.85023, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 2/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 4.3994 - acc: 0.0630 - val_loss: 4.4839 - val_acc: 0.0479
#
# Epoch 00002: val_loss improved from 4.85023 to 4.48388, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 3/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 4.1333 - acc: 0.0952 - val_loss: 4.4950 - val_acc: 0.0491
#
# Epoch 00003: val_loss did not improve from 4.48388
# Epoch 4/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 3.9174 - acc: 0.1274 - val_loss: 4.7812 - val_acc: 0.0443
#
# Epoch 00004: val_loss did not improve from 4.48388
# Epoch 5/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 3.7048 - acc: 0.1519 - val_loss: 4.1790 - val_acc: 0.0982
#
# Epoch 00005: val_loss improved from 4.48388 to 4.17902, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 6/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 3.5014 - acc: 0.1955 - val_loss: 4.5299 - val_acc: 0.0934
#
# Epoch 00006: val_loss did not improve from 4.17902
# Epoch 7/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 3.3187 - acc: 0.2295 - val_loss: 3.9934 - val_acc: 0.1246
#
# Epoch 00007: val_loss improved from 4.17902 to 3.99337, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 8/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 3.1466 - acc: 0.2642 - val_loss: 4.1535 - val_acc: 0.0922
#
# Epoch 00008: val_loss did not improve from 3.99337
# Epoch 9/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.9777 - acc: 0.2990 - val_loss: 4.5086 - val_acc: 0.0982
#
# Epoch 00009: val_loss did not improve from 3.99337
# Epoch 10/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.8325 - acc: 0.3323 - val_loss: 3.7517 - val_acc: 0.1293
#
# Epoch 00010: val_loss improved from 3.99337 to 3.75174, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 11/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.6784 - acc: 0.3653 - val_loss: 3.5473 - val_acc: 0.1713
#
# Epoch 00011: val_loss improved from 3.75174 to 3.54730, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 12/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.5326 - acc: 0.4001 - val_loss: 3.7306 - val_acc: 0.1449
#
# Epoch 00012: val_loss did not improve from 3.54730
# Epoch 13/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.3840 - acc: 0.4407 - val_loss: 3.6904 - val_acc: 0.1449
#
# Epoch 00013: val_loss did not improve from 3.54730
# Epoch 14/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.2314 - acc: 0.4802 - val_loss: 3.5770 - val_acc: 0.1665
#
# Epoch 00014: val_loss did not improve from 3.54730
# Epoch 15/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 2.1218 - acc: 0.5022 - val_loss: 4.8750 - val_acc: 0.1114
#
# Epoch 00015: val_loss did not improve from 3.54730
# Epoch 16/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.9700 - acc: 0.5518 - val_loss: 3.6763 - val_acc: 0.1749
#
# Epoch 00016: val_loss did not improve from 3.54730
# Epoch 17/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.8103 - acc: 0.5936 - val_loss: 3.8612 - val_acc: 0.1449
#
# Epoch 00017: val_loss did not improve from 3.54730
# Epoch 18/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.6879 - acc: 0.6262 - val_loss: 4.7041 - val_acc: 0.1090
#
# Epoch 00018: val_loss did not improve from 3.54730
# Epoch 19/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.5756 - acc: 0.6648 - val_loss: 3.4188 - val_acc: 0.1952
#
# Epoch 00019: val_loss improved from 3.54730 to 3.41879, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 20/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.4327 - acc: 0.7024 - val_loss: 4.3025 - val_acc: 0.1413
#
# Epoch 00020: val_loss did not improve from 3.41879
# Epoch 21/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.2694 - acc: 0.7540 - val_loss: 3.6042 - val_acc: 0.2060
#
# Epoch 00021: val_loss did not improve from 3.41879
# Epoch 22/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.1549 - acc: 0.7880 - val_loss: 3.4595 - val_acc: 0.1844
#
# Epoch 00022: val_loss did not improve from 3.41879
# Epoch 23/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 1.0229 - acc: 0.8269 - val_loss: 3.5825 - val_acc: 0.1796
#
# Epoch 00023: val_loss did not improve from 3.41879
# Epoch 24/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.9337 - acc: 0.8485 - val_loss: 3.9430 - val_acc: 0.1725
#
# Epoch 00024: val_loss did not improve from 3.41879
# Epoch 25/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.8326 - acc: 0.8846 - val_loss: 3.6062 - val_acc: 0.1868
#
# Epoch 00025: val_loss did not improve from 3.41879
# Epoch 26/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.7324 - acc: 0.9093 - val_loss: 4.1382 - val_acc: 0.1557
#
# Epoch 00026: val_loss did not improve from 3.41879
# Epoch 27/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.6416 - acc: 0.9353 - val_loss: 3.3443 - val_acc: 0.2299
#
# Epoch 00027: val_loss improved from 3.41879 to 3.34433, saving model to saved_models/weights.best.from_scratch_adam.hdf5
# Epoch 28/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.5474 - acc: 0.9504 - val_loss: 3.5824 - val_acc: 0.2156
#
# Epoch 00028: val_loss did not improve from 3.34433
# Epoch 29/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.4822 - acc: 0.9603 - val_loss: 3.4766 - val_acc: 0.2060
#
# Epoch 00029: val_loss did not improve from 3.34433
# Epoch 30/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.4284 - acc: 0.9728 - val_loss: 3.6237 - val_acc: 0.1940
#
# Epoch 00030: val_loss did not improve from 3.34433
# Epoch 31/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.3793 - acc: 0.9808 - val_loss: 4.2864 - val_acc: 0.1605
#
# Epoch 00031: val_loss did not improve from 3.34433
# Epoch 32/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.3250 - acc: 0.9844 - val_loss: 3.8034 - val_acc: 0.1916
#
# Epoch 00032: val_loss did not improve from 3.34433
# Epoch 33/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.2715 - acc: 0.9906 - val_loss: 3.7483 - val_acc: 0.2204
#
# Epoch 00033: val_loss did not improve from 3.34433
# Epoch 34/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.2389 - acc: 0.9915 - val_loss: 4.0048 - val_acc: 0.1820
#
# Epoch 00034: val_loss did not improve from 3.34433
# Epoch 35/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.2142 - acc: 0.9945 - val_loss: 3.7875 - val_acc: 0.2096
#
# Epoch 00035: val_loss did not improve from 3.34433
# Epoch 36/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1901 - acc: 0.9958 - val_loss: 3.7737 - val_acc: 0.2168
#
# Epoch 00036: val_loss did not improve from 3.34433
# Epoch 37/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1728 - acc: 0.9958 - val_loss: 3.9095 - val_acc: 0.1940
#
# Epoch 00037: val_loss did not improve from 3.34433
# Epoch 38/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1316 - acc: 0.9981 - val_loss: 4.2753 - val_acc: 0.2048
#
# Epoch 00038: val_loss did not improve from 3.34433
# Epoch 39/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1307 - acc: 0.9979 - val_loss: 4.4801 - val_acc: 0.1677
#
# Epoch 00039: val_loss did not improve from 3.34433
# Epoch 40/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1518 - acc: 0.9948 - val_loss: 3.7392 - val_acc: 0.2251
#
# Epoch 00040: val_loss did not improve from 3.34433
# Epoch 41/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1197 - acc: 0.9978 - val_loss: 3.4738 - val_acc: 0.2275
#
# Epoch 00041: val_loss did not improve from 3.34433
# Epoch 42/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0882 - acc: 0.9985 - val_loss: 4.0007 - val_acc: 0.2144
#
# Epoch 00042: val_loss did not improve from 3.34433
# Epoch 43/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.1079 - acc: 0.9976 - val_loss: 3.5065 - val_acc: 0.2719
#
# Epoch 00043: val_loss did not improve from 3.34433
# Epoch 44/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0760 - acc: 0.9985 - val_loss: 3.5606 - val_acc: 0.2383
#
# Epoch 00044: val_loss did not improve from 3.34433
# Epoch 45/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0653 - acc: 0.9988 - val_loss: 3.7126 - val_acc: 0.2180
#
# Epoch 00045: val_loss did not improve from 3.34433
# Epoch 46/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0811 - acc: 0.9975 - val_loss: 3.3643 - val_acc: 0.2766
#
# Epoch 00046: val_loss did not improve from 3.34433
# Epoch 47/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0619 - acc: 0.9985 - val_loss: 3.6813 - val_acc: 0.2335
#
# Epoch 00047: val_loss did not improve from 3.34433
# Epoch 48/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0529 - acc: 0.9984 - val_loss: 4.5767 - val_acc: 0.1701
#
# Epoch 00048: val_loss did not improve from 3.34433
# Epoch 49/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0995 - acc: 0.9945 - val_loss: 3.9350 - val_acc: 0.2263
#
# Epoch 00049: val_loss did not improve from 3.34433
# Epoch 50/50
# 6680/6680 [==============================] - 11s 2ms/step - loss: 0.0510 - acc: 0.9991 - val_loss: 3.8006 - val_acc: 0.2551
#
# Epoch 00050: val_loss did not improve from 3.34433

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch_adam.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 22.1292%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=150, batch_size=128, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/150
# 6680/6680 [==============================] - 1s 122us/step - loss: 12.9538 - acc: 0.0690 - val_loss: 11.4030 - val_acc: 0.1389
#
# Epoch 00001: val_loss improved from inf to 11.40304, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 2/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 10.1291 - acc: 0.2108 - val_loss: 9.6614 - val_acc: 0.2263
#
# Epoch 00002: val_loss improved from 11.40304 to 9.66145, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 3/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 8.8066 - acc: 0.3189 - val_loss: 8.8491 - val_acc: 0.3042
#
# Epoch 00003: val_loss improved from 9.66145 to 8.84914, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 4/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 8.1655 - acc: 0.3919 - val_loss: 8.4420 - val_acc: 0.3389
#
# Epoch 00004: val_loss improved from 8.84914 to 8.44205, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 5/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 7.8118 - acc: 0.4374 - val_loss: 8.2804 - val_acc: 0.3653
#
# Epoch 00005: val_loss improved from 8.44205 to 8.28042, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 6/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 7.5592 - acc: 0.4681 - val_loss: 8.0781 - val_acc: 0.3892
#
# Epoch 00006: val_loss improved from 8.28042 to 8.07813, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 7/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 7.3661 - acc: 0.4982 - val_loss: 8.0077 - val_acc: 0.3892
#
# Epoch 00007: val_loss improved from 8.07813 to 8.00772, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 8/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 7.2317 - acc: 0.5178 - val_loss: 7.9384 - val_acc: 0.3976
#
# Epoch 00008: val_loss improved from 8.00772 to 7.93841, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 9/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 7.1755 - acc: 0.5341 - val_loss: 7.8640 - val_acc: 0.3988
#
# Epoch 00009: val_loss improved from 7.93841 to 7.86395, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 10/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 7.1370 - acc: 0.5415 - val_loss: 7.8374 - val_acc: 0.4180
#
# Epoch 00010: val_loss improved from 7.86395 to 7.83743, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 11/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 7.1124 - acc: 0.5497 - val_loss: 7.8381 - val_acc: 0.4060
#
# Epoch 00011: val_loss did not improve from 7.83743
# Epoch 12/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 7.1003 - acc: 0.5530 - val_loss: 7.8238 - val_acc: 0.4263
#
# Epoch 00012: val_loss improved from 7.83743 to 7.82380, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 13/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 7.0897 - acc: 0.5579 - val_loss: 7.8104 - val_acc: 0.4132
#
# Epoch 00013: val_loss improved from 7.82380 to 7.81039, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 14/150
# 6680/6680 [==============================] - 0s 52us/step - loss: 7.0853 - acc: 0.5581 - val_loss: 7.7956 - val_acc: 0.4108
#
# Epoch 00014: val_loss improved from 7.81039 to 7.79565, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 15/150
# 6680/6680 [==============================] - 0s 48us/step - loss: 7.0835 - acc: 0.5584 - val_loss: 7.8687 - val_acc: 0.4120
#
# Epoch 00015: val_loss did not improve from 7.79565
# Epoch 16/150
# 6680/6680 [==============================] - 0s 50us/step - loss: 7.0719 - acc: 0.5594 - val_loss: 7.7264 - val_acc: 0.4311
#
# Epoch 00016: val_loss improved from 7.79565 to 7.72642, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 17/150
# 6680/6680 [==============================] - 0s 47us/step - loss: 6.9715 - acc: 0.5563 - val_loss: 7.6227 - val_acc: 0.4204
#
# Epoch 00017: val_loss improved from 7.72642 to 7.62274, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 18/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 6.8282 - acc: 0.5639 - val_loss: 7.5189 - val_acc: 0.4275
#
# Epoch 00018: val_loss improved from 7.62274 to 7.51895, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 19/150
# 6680/6680 [==============================] - 0s 51us/step - loss: 6.6815 - acc: 0.5705 - val_loss: 7.4190 - val_acc: 0.4251
#
# Epoch 00019: val_loss improved from 7.51895 to 7.41900, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 20/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 6.4849 - acc: 0.5802 - val_loss: 7.2691 - val_acc: 0.4299
#
# Epoch 00020: val_loss improved from 7.41900 to 7.26913, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 21/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 6.4392 - acc: 0.5897 - val_loss: 7.1921 - val_acc: 0.4491
#
# Epoch 00021: val_loss improved from 7.26913 to 7.19213, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 22/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 6.4213 - acc: 0.5952 - val_loss: 7.1936 - val_acc: 0.4623
#
# Epoch 00022: val_loss did not improve from 7.19213
# Epoch 23/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 6.4170 - acc: 0.5972 - val_loss: 7.2087 - val_acc: 0.4695
#
# Epoch 00023: val_loss did not improve from 7.19213
# Epoch 24/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 6.4096 - acc: 0.5984 - val_loss: 7.1646 - val_acc: 0.4539
#
# Epoch 00024: val_loss improved from 7.19213 to 7.16464, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 25/150
# 6680/6680 [==============================] - 0s 47us/step - loss: 6.4044 - acc: 0.5999 - val_loss: 7.1665 - val_acc: 0.4695
#
# Epoch 00025: val_loss did not improve from 7.16464
# Epoch 26/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 6.4032 - acc: 0.6003 - val_loss: 7.1742 - val_acc: 0.4683
#
# Epoch 00026: val_loss did not improve from 7.16464
# Epoch 27/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 6.3989 - acc: 0.6000 - val_loss: 7.2050 - val_acc: 0.4611
#
# Epoch 00027: val_loss did not improve from 7.16464
# Epoch 28/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 6.3036 - acc: 0.5993 - val_loss: 7.1183 - val_acc: 0.4527
#
# Epoch 00028: val_loss improved from 7.16464 to 7.11832, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 29/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 6.1832 - acc: 0.6034 - val_loss: 7.0797 - val_acc: 0.4551
#
# Epoch 00029: val_loss improved from 7.11832 to 7.07970, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 30/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 6.0842 - acc: 0.6081 - val_loss: 6.9575 - val_acc: 0.4563
#
# Epoch 00030: val_loss improved from 7.07970 to 6.95751, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 31/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.9056 - acc: 0.6150 - val_loss: 6.7500 - val_acc: 0.4695
#
# Epoch 00031: val_loss improved from 6.95751 to 6.75004, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 32/150
# 6680/6680 [==============================] - 0s 52us/step - loss: 5.8214 - acc: 0.6257 - val_loss: 6.6929 - val_acc: 0.4766
#
# Epoch 00032: val_loss improved from 6.75004 to 6.69286, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 33/150
# 6680/6680 [==============================] - 0s 56us/step - loss: 5.7621 - acc: 0.6302 - val_loss: 6.7900 - val_acc: 0.4743
#
# Epoch 00033: val_loss did not improve from 6.69286
# Epoch 34/150
# 6680/6680 [==============================] - 0s 48us/step - loss: 5.6540 - acc: 0.6346 - val_loss: 6.6598 - val_acc: 0.4743
#
# Epoch 00034: val_loss improved from 6.69286 to 6.65982, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 35/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.5754 - acc: 0.6407 - val_loss: 6.5620 - val_acc: 0.4970
#
# Epoch 00035: val_loss improved from 6.65982 to 6.56197, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 36/150
# 6680/6680 [==============================] - 0s 52us/step - loss: 5.5496 - acc: 0.6466 - val_loss: 6.4706 - val_acc: 0.5006
#
# Epoch 00036: val_loss improved from 6.56197 to 6.47062, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 37/150
# 6680/6680 [==============================] - 0s 47us/step - loss: 5.5359 - acc: 0.6521 - val_loss: 6.4660 - val_acc: 0.5126
#
# Epoch 00037: val_loss improved from 6.47062 to 6.46604, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 38/150
# 6680/6680 [==============================] - 0s 47us/step - loss: 5.5286 - acc: 0.6543 - val_loss: 6.5187 - val_acc: 0.4982
#
# Epoch 00038: val_loss did not improve from 6.46604
# Epoch 39/150
# 6680/6680 [==============================] - 0s 47us/step - loss: 5.5285 - acc: 0.6545 - val_loss: 6.4484 - val_acc: 0.5066
#
# Epoch 00039: val_loss improved from 6.46604 to 6.44840, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 40/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 5.5229 - acc: 0.6548 - val_loss: 6.4381 - val_acc: 0.5138
#
# Epoch 00040: val_loss improved from 6.44840 to 6.43811, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 41/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.5216 - acc: 0.6551 - val_loss: 6.5019 - val_acc: 0.5018
#
# Epoch 00041: val_loss did not improve from 6.43811
# Epoch 42/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.5209 - acc: 0.6551 - val_loss: 6.4594 - val_acc: 0.5138
#
# Epoch 00042: val_loss did not improve from 6.43811
# Epoch 43/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.4992 - acc: 0.6551 - val_loss: 6.4749 - val_acc: 0.5006
#
# Epoch 00043: val_loss did not improve from 6.43811
# Epoch 44/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.4192 - acc: 0.6578 - val_loss: 6.3183 - val_acc: 0.5138
#
# Epoch 00044: val_loss improved from 6.43811 to 6.31831, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 45/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.4041 - acc: 0.6629 - val_loss: 6.3353 - val_acc: 0.5162
#
# Epoch 00045: val_loss did not improve from 6.31831
# Epoch 46/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.4001 - acc: 0.6629 - val_loss: 6.3400 - val_acc: 0.5269
#
# Epoch 00046: val_loss did not improve from 6.31831
# Epoch 47/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3997 - acc: 0.6639 - val_loss: 6.3907 - val_acc: 0.5174
#
# Epoch 00047: val_loss did not improve from 6.31831
# Epoch 48/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.4008 - acc: 0.6629 - val_loss: 6.3191 - val_acc: 0.5317
#
# Epoch 00048: val_loss did not improve from 6.31831
# Epoch 49/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 5.3981 - acc: 0.6638 - val_loss: 6.4117 - val_acc: 0.5210
#
# Epoch 00049: val_loss did not improve from 6.31831
# Epoch 50/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3984 - acc: 0.6635 - val_loss: 6.3506 - val_acc: 0.5257
#
# Epoch 00050: val_loss did not improve from 6.31831
# Epoch 51/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3989 - acc: 0.6636 - val_loss: 6.3446 - val_acc: 0.5234
#
# Epoch 00051: val_loss did not improve from 6.31831
# Epoch 52/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.4003 - acc: 0.6633 - val_loss: 6.3092 - val_acc: 0.5317
#
# Epoch 00052: val_loss improved from 6.31831 to 6.30922, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 53/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3983 - acc: 0.6636 - val_loss: 6.4006 - val_acc: 0.5186
#
# Epoch 00053: val_loss did not improve from 6.30922
# Epoch 54/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3982 - acc: 0.6636 - val_loss: 6.3642 - val_acc: 0.5353
#
# Epoch 00054: val_loss did not improve from 6.30922
# Epoch 55/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3986 - acc: 0.6636 - val_loss: 6.3440 - val_acc: 0.5365
#
# Epoch 00055: val_loss did not improve from 6.30922
# Epoch 56/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3994 - acc: 0.6635 - val_loss: 6.3591 - val_acc: 0.5246
#
# Epoch 00056: val_loss did not improve from 6.30922
# Epoch 57/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.3969 - acc: 0.6639 - val_loss: 6.3986 - val_acc: 0.5257
#
# Epoch 00057: val_loss did not improve from 6.30922
# Epoch 58/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3979 - acc: 0.6639 - val_loss: 6.3363 - val_acc: 0.5174
#
# Epoch 00058: val_loss did not improve from 6.30922
# Epoch 59/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3984 - acc: 0.6633 - val_loss: 6.3413 - val_acc: 0.5317
#
# Epoch 00059: val_loss did not improve from 6.30922
# Epoch 60/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3996 - acc: 0.6641 - val_loss: 6.3223 - val_acc: 0.5269
#
# Epoch 00060: val_loss did not improve from 6.30922
# Epoch 61/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3988 - acc: 0.6638 - val_loss: 6.3968 - val_acc: 0.5317
#
# Epoch 00061: val_loss did not improve from 6.30922
# Epoch 62/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3988 - acc: 0.6638 - val_loss: 6.3165 - val_acc: 0.5413
#
# Epoch 00062: val_loss did not improve from 6.30922
# Epoch 63/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3984 - acc: 0.6636 - val_loss: 6.3780 - val_acc: 0.5246
#
# Epoch 00063: val_loss did not improve from 6.30922
# Epoch 64/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3989 - acc: 0.6644 - val_loss: 6.3216 - val_acc: 0.5329
#
# Epoch 00064: val_loss did not improve from 6.30922
# Epoch 65/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3985 - acc: 0.6642 - val_loss: 6.3998 - val_acc: 0.5341
#
# Epoch 00065: val_loss did not improve from 6.30922
# Epoch 66/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3987 - acc: 0.6639 - val_loss: 6.3836 - val_acc: 0.5269
#
# Epoch 00066: val_loss did not improve from 6.30922
# Epoch 67/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3967 - acc: 0.6644 - val_loss: 6.3534 - val_acc: 0.5293
#
# Epoch 00067: val_loss did not improve from 6.30922
# Epoch 68/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3969 - acc: 0.6639 - val_loss: 6.4214 - val_acc: 0.5365
#
# Epoch 00068: val_loss did not improve from 6.30922
# Epoch 69/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3988 - acc: 0.6636 - val_loss: 6.3650 - val_acc: 0.5329
#
# Epoch 00069: val_loss did not improve from 6.30922
# Epoch 70/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3977 - acc: 0.6639 - val_loss: 6.4050 - val_acc: 0.5269
#
# Epoch 00070: val_loss did not improve from 6.30922
# Epoch 71/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3990 - acc: 0.6639 - val_loss: 6.3827 - val_acc: 0.5365
#
# Epoch 00071: val_loss did not improve from 6.30922
# Epoch 72/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3977 - acc: 0.6638 - val_loss: 6.3825 - val_acc: 0.5365
#
# Epoch 00072: val_loss did not improve from 6.30922
# Epoch 73/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3968 - acc: 0.6642 - val_loss: 6.3736 - val_acc: 0.5341
#
# Epoch 00073: val_loss did not improve from 6.30922
# Epoch 74/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3970 - acc: 0.6641 - val_loss: 6.3739 - val_acc: 0.5246
#
# Epoch 00074: val_loss did not improve from 6.30922
# Epoch 75/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3988 - acc: 0.6639 - val_loss: 6.4181 - val_acc: 0.5377
#
# Epoch 00075: val_loss did not improve from 6.30922
# Epoch 76/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.3967 - acc: 0.6639 - val_loss: 6.3768 - val_acc: 0.5329
#
# Epoch 00076: val_loss did not improve from 6.30922
# Epoch 77/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3994 - acc: 0.6641 - val_loss: 6.3601 - val_acc: 0.5329
# Epoch 00077: val_loss did not improve from 6.30922
# Epoch 78/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3976 - acc: 0.6642 - val_loss: 6.3625 - val_acc: 0.5341
#
# Epoch 00078: val_loss did not improve from 6.30922
# Epoch 79/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3980 - acc: 0.6642 - val_loss: 6.3850 - val_acc: 0.5341
#
# Epoch 00079: val_loss did not improve from 6.30922
# Epoch 80/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3992 - acc: 0.6644 - val_loss: 6.3842 - val_acc: 0.5317
#
# Epoch 00080: val_loss did not improve from 6.30922
# Epoch 81/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3994 - acc: 0.6642 - val_loss: 6.3958 - val_acc: 0.5341
#
# Epoch 00081: val_loss did not improve from 6.30922
# Epoch 82/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3978 - acc: 0.6642 - val_loss: 6.4012 - val_acc: 0.5269
#
# Epoch 00082: val_loss did not improve from 6.30922
# Epoch 83/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3981 - acc: 0.6644 - val_loss: 6.3847 - val_acc: 0.5353
#
# Epoch 00083: val_loss did not improve from 6.30922
# Epoch 84/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3976 - acc: 0.6642 - val_loss: 6.4042 - val_acc: 0.5341
#
# Epoch 00084: val_loss did not improve from 6.30922
# Epoch 85/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.3982 - acc: 0.6644 - val_loss: 6.3876 - val_acc: 0.5329
#
# Epoch 00085: val_loss did not improve from 6.30922
# Epoch 86/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3977 - acc: 0.6642 - val_loss: 6.3924 - val_acc: 0.5329
#
# Epoch 00086: val_loss did not improve from 6.30922
# Epoch 87/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3988 - acc: 0.6644 - val_loss: 6.3945 - val_acc: 0.5365
#
# Epoch 00087: val_loss did not improve from 6.30922
# Epoch 88/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3996 - acc: 0.6641 - val_loss: 6.3907 - val_acc: 0.5353
#
# Epoch 00088: val_loss did not improve from 6.30922
# Epoch 89/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3992 - acc: 0.6641 - val_loss: 6.3654 - val_acc: 0.5353
#
# Epoch 00089: val_loss did not improve from 6.30922
# Epoch 90/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3973 - acc: 0.6642 - val_loss: 6.3694 - val_acc: 0.5401
#
# Epoch 00090: val_loss did not improve from 6.30922
# Epoch 91/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3979 - acc: 0.6644 - val_loss: 6.4407 - val_acc: 0.5281
#
# Epoch 00091: val_loss did not improve from 6.30922
# Epoch 92/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3977 - acc: 0.6641 - val_loss: 6.4097 - val_acc: 0.5293
#
# Epoch 00092: val_loss did not improve from 6.30922
# Epoch 93/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3984 - acc: 0.6642 - val_loss: 6.4252 - val_acc: 0.5329
#
# Epoch 00093: val_loss did not improve from 6.30922
# Epoch 94/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.4004 - acc: 0.6641 - val_loss: 6.3816 - val_acc: 0.5365
#
# Epoch 00094: val_loss did not improve from 6.30922
# Epoch 95/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3986 - acc: 0.6641 - val_loss: 6.4517 - val_acc: 0.5269
#
# Epoch 00095: val_loss did not improve from 6.30922
# Epoch 96/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3985 - acc: 0.6641 - val_loss: 6.4160 - val_acc: 0.5389
#
# Epoch 00096: val_loss did not improve from 6.30922
# Epoch 97/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3994 - acc: 0.6642 - val_loss: 6.4120 - val_acc: 0.5377
#
# Epoch 00097: val_loss did not improve from 6.30922
# Epoch 98/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.3987 - acc: 0.6642 - val_loss: 6.4369 - val_acc: 0.5329
#
# Epoch 00098: val_loss did not improve from 6.30922
# Epoch 99/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3983 - acc: 0.6642 - val_loss: 6.3988 - val_acc: 0.5317
#
# Epoch 00099: val_loss did not improve from 6.30922
# Epoch 100/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 5.3990 - acc: 0.6641 - val_loss: 6.4183 - val_acc: 0.5389
#
# Epoch 00100: val_loss did not improve from 6.30922
# Epoch 101/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3990 - acc: 0.6641 - val_loss: 6.3985 - val_acc: 0.5377
#
# Epoch 00101: val_loss did not improve from 6.30922
# Epoch 102/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3989 - acc: 0.6642 - val_loss: 6.4166 - val_acc: 0.5341
#
# Epoch 00102: val_loss did not improve from 6.30922
# Epoch 103/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3967 - acc: 0.6647 - val_loss: 6.4206 - val_acc: 0.5246
#
# Epoch 00103: val_loss did not improve from 6.30922
# Epoch 104/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3994 - acc: 0.6642 - val_loss: 6.4194 - val_acc: 0.5389
#
# Epoch 00104: val_loss did not improve from 6.30922
# Epoch 105/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3976 - acc: 0.6644 - val_loss: 6.4177 - val_acc: 0.5353
#
# Epoch 00105: val_loss did not improve from 6.30922
# Epoch 106/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3983 - acc: 0.6642 - val_loss: 6.4304 - val_acc: 0.5353
#
# Epoch 00106: val_loss did not improve from 6.30922
# Epoch 107/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3988 - acc: 0.6644 - val_loss: 6.4528 - val_acc: 0.5317
#
# Epoch 00107: val_loss did not improve from 6.30922
# Epoch 108/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3988 - acc: 0.6644 - val_loss: 6.4537 - val_acc: 0.5353
#
# Epoch 00108: val_loss did not improve from 6.30922
# Epoch 109/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3972 - acc: 0.6645 - val_loss: 6.4293 - val_acc: 0.5222
#
# Epoch 00109: val_loss did not improve from 6.30922
# Epoch 110/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3979 - acc: 0.6644 - val_loss: 6.4264 - val_acc: 0.5377
#
# Epoch 00110: val_loss did not improve from 6.30922
# Epoch 111/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3980 - acc: 0.6642 - val_loss: 6.4280 - val_acc: 0.5353
#
# Epoch 00111: val_loss did not improve from 6.30922
# Epoch 112/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3990 - acc: 0.6642 - val_loss: 6.4216 - val_acc: 0.5246
#
# Epoch 00112: val_loss did not improve from 6.30922
# Epoch 113/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3982 - acc: 0.6644 - val_loss: 6.4436 - val_acc: 0.5281
#
# Epoch 00113: val_loss did not improve from 6.30922
# Epoch 114/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3995 - acc: 0.6641 - val_loss: 6.4338 - val_acc: 0.5377
#
# Epoch 00114: val_loss did not improve from 6.30922
# Epoch 115/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3993 - acc: 0.6642 - val_loss: 6.4343 - val_acc: 0.5317
#
# Epoch 00115: val_loss did not improve from 6.30922
# Epoch 116/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3981 - acc: 0.6644 - val_loss: 6.4179 - val_acc: 0.5281
#
# Epoch 00116: val_loss did not improve from 6.30922
# Epoch 117/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3982 - acc: 0.6644 - val_loss: 6.3997 - val_acc: 0.5329
#
# Epoch 00117: val_loss did not improve from 6.30922
# Epoch 118/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3976 - acc: 0.6645 - val_loss: 6.4563 - val_acc: 0.5329
#
# Epoch 00118: val_loss did not improve from 6.30922
# Epoch 119/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3974 - acc: 0.6645 - val_loss: 6.4144 - val_acc: 0.5317
#
# Epoch 00119: val_loss did not improve from 6.30922
# Epoch 120/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3977 - acc: 0.6645 - val_loss: 6.4713 - val_acc: 0.5353
#
# Epoch 00120: val_loss did not improve from 6.30922
# Epoch 121/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3982 - acc: 0.6642 - val_loss: 6.4288 - val_acc: 0.5365
#
# Epoch 00121: val_loss did not improve from 6.30922
# Epoch 122/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3988 - acc: 0.6642 - val_loss: 6.4468 - val_acc: 0.5305
#
# Epoch 00122: val_loss did not improve from 6.30922
# Epoch 123/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3976 - acc: 0.6644 - val_loss: 6.4538 - val_acc: 0.5377
#
# Epoch 00123: val_loss did not improve from 6.30922
# Epoch 124/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3995 - acc: 0.6642 - val_loss: 6.4748 - val_acc: 0.5377
#
# Epoch 00124: val_loss did not improve from 6.30922
# Epoch 125/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3980 - acc: 0.6644 - val_loss: 6.4631 - val_acc: 0.5365
#
# Epoch 00125: val_loss did not improve from 6.30922
# Epoch 126/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3997 - acc: 0.6642 - val_loss: 6.4455 - val_acc: 0.5329
#
# Epoch 00126: val_loss did not improve from 6.30922
# Epoch 127/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3989 - acc: 0.6642 - val_loss: 6.4450 - val_acc: 0.5317
#
# Epoch 00127: val_loss did not improve from 6.30922
# Epoch 128/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3978 - acc: 0.6645 - val_loss: 6.4237 - val_acc: 0.5353
#
# Epoch 00128: val_loss did not improve from 6.30922
# Epoch 129/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3987 - acc: 0.6642 - val_loss: 6.4491 - val_acc: 0.5317
#
# Epoch 00129: val_loss did not improve from 6.30922
# Epoch 130/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3985 - acc: 0.6645 - val_loss: 6.4406 - val_acc: 0.5341
#
# Epoch 00130: val_loss did not improve from 6.30922
# Epoch 131/150
# 6680/6680 [==============================] - 0s 48us/step - loss: 5.3987 - acc: 0.6644 - val_loss: 6.4903 - val_acc: 0.5317
#
# Epoch 00131: val_loss did not improve from 6.30922
# Epoch 132/150
# 6680/6680 [==============================] - 0s 46us/step - loss: 5.3979 - acc: 0.6644 - val_loss: 6.4369 - val_acc: 0.5246
#
# Epoch 00132: val_loss did not improve from 6.30922
# Epoch 133/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.3976 - acc: 0.6644 - val_loss: 6.4339 - val_acc: 0.5329
#
# Epoch 00133: val_loss did not improve from 6.30922
# Epoch 134/150
# 6680/6680 [==============================] - 0s 45us/step - loss: 5.3980 - acc: 0.6645 - val_loss: 6.4543 - val_acc: 0.5365
#
# Epoch 00134: val_loss did not improve from 6.30922
# Epoch 135/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3988 - acc: 0.6644 - val_loss: 6.4212 - val_acc: 0.5305
#
# Epoch 00135: val_loss did not improve from 6.30922
# Epoch 136/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3999 - acc: 0.6641 - val_loss: 6.4289 - val_acc: 0.5317
#
# Epoch 00136: val_loss did not improve from 6.30922
# Epoch 137/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3984 - acc: 0.6644 - val_loss: 6.4273 - val_acc: 0.5341
#
# Epoch 00137: val_loss did not improve from 6.30922
# Epoch 138/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3989 - acc: 0.6642 - val_loss: 6.4232 - val_acc: 0.5317
#
# Epoch 00138: val_loss did not improve from 6.30922
# Epoch 139/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3989 - acc: 0.6642 - val_loss: 6.4591 - val_acc: 0.5317
#
# Epoch 00139: val_loss did not improve from 6.30922
# Epoch 140/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3964 - acc: 0.6648 - val_loss: 6.4527 - val_acc: 0.5341
#
# Epoch 00140: val_loss did not improve from 6.30922
# Epoch 141/150
# 6680/6680 [==============================] - 0s 44us/step - loss: 5.3992 - acc: 0.6642 - val_loss: 6.4131 - val_acc: 0.5317
#
# Epoch 00141: val_loss did not improve from 6.30922
# Epoch 142/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3967 - acc: 0.6647 - val_loss: 6.4783 - val_acc: 0.5341
#
# Epoch 00142: val_loss did not improve from 6.30922
# Epoch 143/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3983 - acc: 0.6642 - val_loss: 6.4449 - val_acc: 0.5305
#
# Epoch 00143: val_loss did not improve from 6.30922
# Epoch 144/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3983 - acc: 0.6644 - val_loss: 6.4412 - val_acc: 0.5353
#
# Epoch 00144: val_loss did not improve from 6.30922
# Epoch 145/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3978 - acc: 0.6645 - val_loss: 6.4544 - val_acc: 0.5305
#
# Epoch 00145: val_loss did not improve from 6.30922
# Epoch 146/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.4000 - acc: 0.6642 - val_loss: 6.4653 - val_acc: 0.5401
#
# Epoch 00146: val_loss did not improve from 6.30922
# Epoch 147/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3982 - acc: 0.6644 - val_loss: 6.4565 - val_acc: 0.5353
#
# Epoch 00147: val_loss did not improve from 6.30922
# Epoch 148/150
# 6680/6680 [==============================] - 0s 42us/step - loss: 5.3981 - acc: 0.6644 - val_loss: 6.4629 - val_acc: 0.5329
#
# Epoch 00148: val_loss did not improve from 6.30922
# Epoch 149/150
# 6680/6680 [==============================] - 0s 41us/step - loss: 5.3995 - acc: 0.6642 - val_loss: 6.4621 - val_acc: 0.5353
#
# Epoch 00149: val_loss did not improve from 6.30922
# Epoch 150/150
# 6680/6680 [==============================] - 0s 43us/step - loss: 5.3987 - acc: 0.6642 - val_loss: 6.4609 - val_acc: 0.5377
#
# Epoch 00150: val_loss did not improve from 6.30922

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 51.4354%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

def draw_dog_face(path, ax=None, dog_breed=None):
    img = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)
    ax.imshow(img)
    ax.set_title(dog_breed)

sample_dog_images = dog_files_short[:25]

fig = plt.figure(figsize=(45, 45))

for i, img in enumerate(sample_dog_images):
    ax = fig.add_subplot(5, 5, i + 1, xticks=[], yticks=[])
    dog_breed = VGG16_predict_breed(img)
    original_dog_breed = sample_dog_images[i].split('/')[2].split('.')[1]
#     print("Image {}:\n\t Original Breed: {}\n\t Predicted Breed: {}".format(i+1, 
#                                                                             original_dog_breed, 
#                                                                             dog_breed))
    draw_dog_face(path=img, ax=ax, dog_breed=dog_breed)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#
# ResourceExhaustedError: OOM when allocating tensor of shape [] and type float
# 	 [[Node: block1_conv1_94/random_uniform/sub = Const[dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0.199501872>, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-37-af2b8fa0e375> in <module>()
#      20 for i, img in enumerate(sample_dog_images):
#      21     ax = fig.add_subplot(5, 5, i + 1, xticks=[], yticks=[])
# ---> 22     dog_breed = VGG16_predict_breed(img)
#      23     original_dog_breed = sample_dog_images[i].split('/')[2].split('.')[1]
#      24 #     print("Image {}:\n\t Original Breed: {}\n\t Predicted Breed: {}".format(i+1,
#
# <ipython-input-37-af2b8fa0e375> in VGG16_predict_breed(img_path)
#       3 def VGG16_predict_breed(img_path):
#       4     # extract bottleneck features
# ----> 5     bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
#       6     # obtain predicted vector
#       7     predicted_vector = VGG16_model.predict(bottleneck_feature)
#
# ~/Documents/Udacity_Machine_Learning/dog-project/extract_bottleneck_features.py in extract_VGG16(tensor)
#       1 def extract_VGG16(tensor):
#       2         from keras.applications.vgg16 import VGG16, preprocess_input
# ----> 3         return VGG16(weights='imagenet', include_top=False).predict(preprocess_input(tensor))
#       4
#       5 def extract_VGG19(tensor):
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras_applications/vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes)
#     216                 cache_subdir='models',
#     217                 file_hash='6d6bbae143d832006294945121d1f1fc')
# --> 218         model.load_weights(weights_path)
#     219         if backend.backend() == 'theano':
#     220             keras_utils.convert_all_kernels_in_model(model)
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1159             else:
#    1160                 saving.load_weights_from_hdf5_group(
# -> 1161                     f, self.layers, reshape=reshape)
#    1162
#    1163     def _updated_config(self):
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/engine/saving.py in load_weights_from_hdf5_group(f, layers, reshape)
#     926                              ' elements.')
#     927         weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 928     K.batch_set_value(weight_value_tuples)
#     929
#     930
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2438             assign_ops.append(assign_op)
#    2439             feed_dict[assign_placeholder] = value
# -> 2440         get_session().run(assign_ops, feed_dict=feed_dict)
#    2441
#    2442
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     202                     v._keras_initialized = True
#     203                 if uninitialized_vars:
# --> 204                     session.run(tf.variables_initializer(uninitialized_vars))
#     205     # hack for list_devices() function.
#     206     # list_devices() function is not available under tensorflow r1.3.
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1289         except KeyError:
#    1290           pass
# -> 1291       raise type(e)(node_def, op, message)
#    1292
#    1293   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor of shape [] and type float
# 	 [[Node: block1_conv1_94/random_uniform/sub = Const[dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0.199501872>, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# Caused by op 'block1_conv1_94/random_uniform/sub', defined at:
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-37-af2b8fa0e375>", line 22, in <module>
#     dog_breed = VGG16_predict_breed(img)
#   File "<ipython-input-37-af2b8fa0e375>", line 5, in VGG16_predict_breed
#     bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
#   File "/home/mbgorantla/Documents/Udacity_Machine_Learning/dog-project/extract_bottleneck_features.py", line 3, in extract_VGG16
#     return VGG16(weights='imagenet', include_top=False).predict(preprocess_input(tensor))
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras_applications/vgg16.py", line 116, in VGG16
#     name='block1_conv1')(img_input)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/engine/base_layer.py", line 431, in __call__
#     self.build(unpack_singleton(input_shapes))
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/layers/convolutional.py", line 138, in build
#     constraint=self.kernel_constraint)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/engine/base_layer.py", line 249, in add_weight
#     weight = K.variable(initializer(shape),
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/initializers.py", line 218, in __call__
#     dtype=dtype, seed=self.seed)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py", line 4049, in random_uniform
#     dtype=dtype, seed=seed)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/ops/random_ops.py", line 243, in random_uniform
#     return math_ops.add(rnd * (maxval - minval), minval, name=name)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py", line 850, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/ops/gen_math_ops.py", line 8188, in sub
#     "Sub", x=x, y=y, name=name)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py", line 454, in new_func
#     return func(*args, **kwargs)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3155, in create_op
#     op_def=op_def)
#   File "/home/mbgorantla/anaconda3/envs/Machine_Learning/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1717, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor of shape [] and type float
# 	 [[Node: block1_conv1_94/random_uniform/sub = Const[dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0.199501872>, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
